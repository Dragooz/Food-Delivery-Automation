# %%
from datetime import datetime, timedelta
from mypackage.helpers import Helper
from mypackage.constants import COLOR_DICT, SORTER, KK_DICT, SHOP_NAME, ALL_SERIES
import io
from apiclient import errors
import re

# %%
import os
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google.oauth2 import service_account
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from googleapiclient.http import MediaFileUpload, MediaIoBaseDownload

from httplib2 import Http
import pandas as pd
from dotenv import load_dotenv

from mypackage.helpers import Helper
from mypackage.constants import SHOP_NAME

from openpyxl import load_workbook, Workbook
import logging

#create a logger
logging.basicConfig(level=logging.INFO)

#setup
# dotenv_path = '/.env'
load_dotenv()

SERVICE_ACCOUNT = os.getenv('SERVICE_ACCOUNT') #The service acc used to create files.
GOOGLE_SHEET_ID = os.getenv("GOOGLE_SHEET_ID") #the shared google sheet that user can access and input ID
SHARED_PARENT_FOLDER_ID = os.getenv("SHARED_PARENT_FOLDER_ID") #the shared parent folder on personal acc

SCOPES = ["https://www.googleapis.com/auth/forms.body", "https://www.googleapis.com/auth/drive", "https://www.googleapis.com/auth/drive.file", "https://www.googleapis.com/auth/forms.responses.readonly", "https://www.googleapis.com/auth/spreadsheets.readonly"]

credentials = service_account.Credentials.from_service_account_file(SERVICE_ACCOUNT, scopes=SCOPES)
# credentials = None

# if os.path.exists("token.json"):
#     credentials = Credentials.from_authorized_user_file('token.json', SCOPES)
# if not credentials or not credentials.valid:
#     if credentials and credentials.expired and credentials.refresh_token:
#         credentials.refresh(Request())
#     else:
#         flow = InstalledAppFlow.from_client_secrets_file(CLIENT_FILE, SCOPES)
#         credentials = flow.run_local_server(port=0)
#     with open('token.json', 'w') as token:
#         token.write(credentials.to_json())

ks_hyk_helper_obj = Helper.KS_HYK()
kimseng_helper_obj = Helper.KimSeng()
# jackson_helper_obj = Helper.Jackson()
hyk_helper_obj = Helper.HYK()

today_str = (datetime.today() + timedelta(days=1)).strftime('%d-%m-%Y') #today_str = date that file should be run. Hence if today is 04/01/2023, then today str should be 05/01/2023 so that 05/01/2023 row will be read.
today_str = '30-01-2023'

# files = service_drive.files().list( q=f"name='KS&J&HYK' and mimeType='application/vnd.google-apps.folder' and trashed=false and parents in '{SHARED_PARENT_FOLDER_ID}' " ,
#                                        spaces='drive').execute()['files']

# %%
service_form = build('forms', 'v1', credentials=credentials) #forms
service_sheet = build('sheets', 'v4', credentials=credentials)
service_drive = build('drive', 'v3', credentials=credentials)
# GOOGLE_SHEET_ID = '1ey4vDFNm3qIogHpLeUVkABsgIbD0UskUAdTnvuentng'

def create_excel_input(formId):
    '''
    Retrieve google sheet and create csv locally
    '''
    # Retrieve google sheet
    form = service_form.forms().get(formId=formId).execute()
    print("form['linkedSheetId']", form['linkedSheetId'])
    sheet_res = service_sheet.spreadsheets().get(spreadsheetId=form['linkedSheetId']).execute()
    dataset = service_sheet.spreadsheets().values().get(
        spreadsheetId= sheet_res['spreadsheetId'],
        range=sheet_res['sheets'][0]['properties']['title'],
        majorDimension= 'ROWS',
    ).execute()
    df = pd.DataFrame(dataset['values'])
    df = df.rename(columns=df.iloc[0]).drop(df.index[0])
    # df = pd.concat([df, df])
    columns_name = list(df.columns)
    column_d, column_e, column_f = columns_name[3], columns_name[4], columns_name[5]
    if df.duplicated(subset=[column_d, column_e, column_f], keep=False).any() == True:
        # print("df_original: ", df)
        df_duplicated = df.loc[df.duplicated(subset=[column_d, column_e, column_f])]
        # print("df_duplicated: ", df_duplicated)
        file_name_duplicated = f"{sheet_res['properties']['title'].replace('/', '-')}_duplicated.csv"
        df_duplicated.to_csv(file_name_duplicated, index=False)
        df.drop_duplicates(subset=[column_d, column_e, column_f], keep='first', inplace=True)
        # print("df after drop inplace: ", df)
    else:
        file_name_duplicated="None"
    
    # shop_name = SHOP_NAME['JS']
    # shop_input_path = os.path.join(shop_name, 'input')
    # final_path = os.path.join(shop_input_path, f"{sheet_res['properties']['title'].replace('/', '-')}_Generated.csv")
    file_name_real = f"{sheet_res['properties']['title'].replace('/', '-')}_Generated.csv"
    df.to_csv(file_name_real, index=False)
    if file_name_duplicated != "None":
        return df, [file_name_real, file_name_duplicated]
    return df, [file_name_real]

def create_all_output(df_input, is_kimseng):
    if is_kimseng:
        excel_output_path, image_output_path, txt_name_list = kimseng_helper_obj.run_ks(df_input, today_str)
        return excel_output_path, image_output_path, txt_name_list
    else:
        excel_output_path, image_output_path, txt_name_list = hyk_helper_obj.run_hyk(df_input, today_str)
        return excel_output_path, image_output_path, txt_name_list
# Out:
# INFO:googleapiclient.discovery_cache:file_cache is only supported with oauth2client<4.0.0
# INFO:googleapiclient.discovery_cache:file_cache is only supported with oauth2client<4.0.0
# INFO:googleapiclient.discovery_cache:file_cache is only supported with oauth2client<4.0.0

# %%
# service_drive.permissions().list(fileId=ks_j_hyk_folder_id).execute()
# service_drive.permissions().delete(permissionId='03183278425046065265', fileId = ks_j_hyk_folder_id).execute()

# res = service_drive.permissions().list(fileId=kimseng_folder_output_today_id).execute()

# permissionId = ""
# if res['permissions'].length > 0:
#     permissionId = res['permissions'][0].get('id')

# if permissionId != "":
    
# print(len(res['permissions'])

# %%
# service_drive.files().delete(fileId=ks_j_hyk_folder_id).execute()
# service_drive.permissions().create(fileId=ks_j_hyk_folder_id, body={
#       'emailAddress': 'byichonggoh@gmail.com',
#       'type': 'user',
#       'role': 'reader',
#   }).execute()

# file_metadata = {
#     'name': f"testing folder",
#     'mimeType': 'application/vnd.google-apps.folder',
# }

# res_file = service_drive.files().create(body=file_metadata, supportsAllDrives=True, fields='id').execute()
# res_file
# new_permission = {
#       'type': 'user',
#       'role': 'reader',
#       'emailAddress': 'byichonggoh@gmail.com',
#   }
# service_drive.permissions().create(fileId='1OgSojD3wHJxjYiLrd8tjKbhB1RoBsipr', body=new_permission, fields='id').execute()

# service_drive.files().list(q=f"mimeType='application/vnd.google-apps.folder' and trashed=false and parents in '{SHARED_PARENT_FOLDER_ID}'").execute()
# service_drive.files().list( q=f"name='KS&J&HYK' and mimeType='application/vnd.google-apps.folder' and trashed=false and parents in '{SHARED_PARENT_FOLDER_ID}'", spaces='drive',).execute()['files']
# res = service_drive.files().list().execute()['files']
# for r in res:
#     file_id = r['id']
#     print(r)
#     try:
#         service_drive.files().delete(fileId=file_id).execute()
#     except HttpError as e:
#         print(e)

# %%
# service_drive.files().list( q=f"name='KS&J&HYK' and mimeType='application/vnd.google-apps.folder' and trashed=false and parents in '{SHARED_PARENT_FOLDER_ID}'", spaces='drive',).execute()['files']
# res = service_drive.files().list().execute()['files']
# for r in res:
#     file_id = r['id']
#     print(r)
#     try:
#         service_drive.files().delete(fileId=file_id).execute()
#     except HttpError as e:
#         print(e)

# %%
# service_drive.files().list().execute()['files']

# %%
#Search or Create folders in google drive
def get_or_create_folder_id(file_name, parents=None, is_root=False):
    '''
    file_name: File's Name
    parents: [File Id]
    '''
    file_id = ''
    # if is_root:
    files = service_drive.files().list( q=f"name='{file_name}' and mimeType='application/vnd.google-apps.folder' and trashed=false and parents in '{parents[0]}' " ,
                                    spaces='drive').execute()['files']
    # else:
    #   files = service_drive.files().list( q=f"name='{file_name}' and mimeType='application/vnd.google-apps.folder' and trashed=false" ,
    #                                    spaces='drive').execute()['files']
    if len(files) > 0: #exist
        print(f"{file_name} exist. ")
        file_id = files[0].get('id')
        return file_id
    #create folder
    file_metadata = {
            'name': f"{file_name}",
            'mimeType': 'application/vnd.google-apps.folder',
            'parents': parents, 
        }

    res_file = service_drive.files().create(body=file_metadata, supportsAllDrives=True, fields='id').execute()
    file_id = res_file.get('id')
    # service_drive.permissions().create(fileId = file_id, body={"role": "reader", "type":"user", "emailAddress": "byichonggoh@gmail.com"}, supportsAllDrives=True, fields='id').execute()
    return file_id

#create stuff
#so the idea here is to export to files, upload the files, and delete the files. can be triggered through the form id
logging.info("Creating Folders if doesn't exist...")
ks_j_hyk_folder_id = get_or_create_folder_id('KS&J&HYK', [SHARED_PARENT_FOLDER_ID], is_root=True)
input_folder_id = get_or_create_folder_id('Input', [ks_j_hyk_folder_id])
output_folder_id = get_or_create_folder_id('Output', [ks_j_hyk_folder_id])
output_folder_today_id = get_or_create_folder_id(f'{today_str} output', [output_folder_id])

# kimseng_folder_id = get_or_create_folder_id('KimSeng', [ks_j_hyk_folder_id])
# kimseng_folder_input_id = get_or_create_folder_id('KimSengInput', [kimseng_folder_id])
# kimseng_folder_output_id = get_or_create_folder_id('KimSengOutput', [kimseng_folder_id])
# kimseng_folder_output_today_id = get_or_create_folder_id(f'{today_str} Koutput', [kimseng_folder_output_id])

# jackson_folder_id = get_or_create_folder_id('JDinner', [ks_j_hyk_folder_id])
# jackson_folder_input_id = get_or_create_folder_id('JDinnerInput', [jackson_folder_id])
# jackson_folder_output_id = get_or_create_folder_id('JDinnerOutput', [jackson_folder_id])
# jackson_folder_output_today_id = get_or_create_folder_id(f'{today_str} Joutput', [jackson_folder_output_id])

# hyk_folder_id = get_or_create_folder_id('HYK', [ks_j_hyk_folder_id])
# hyk_folder_input_id = get_or_create_folder_id('HYKInput', [hyk_folder_id])
# hyk_folder_output_id = get_or_create_folder_id('HYKOutput', [hyk_folder_id])
# hyk_folder_output_today_id = get_or_create_folder_id(f'{today_str} HYKOutput', [hyk_folder_output_id])

#put csv into input
# f"{sheet_res['properties']['title'].replace('/', '-')}_Generated"
# Out:
# INFO:root:Creating Folders if doesn't exist...
# KS&J&HYK exist.
# Input exist.
# Output exist.
# 30-01-2023 output exist.

# %%
def file_exist(file_name, mimetype):
    files = service_drive.files().list( q=f"name = '{file_name}' and mimeType = '{mimetype}' and trashed = false" ,
                                       spaces='drive',).execute()['files']
    if len(files) > 0: #exist
        return files[0].get('id')
    return False

def upload_input_file(file_name, parents):
    '''
    Input:
    file_name: File's Name
    parents: [File Id]
    '''
    file_metadata = {'name': file_name,'parents': parents,}
    file_media = MediaFileUpload(file_name, mimetype='text/csv')
    # if file_id := file_exist(file_name, 'text/csv'):
    #     service_drive.files().update(fileId=file_id, body={'name': file_name}, media_body=file_media, fields='id').execute()['id']
    # else:
    file_id = service_drive.files().create(body=file_metadata, media_body=file_media, fields='id').execute()['id']
    file_media = None #To stop reading the file to allow delete

def upload_output_file(parents, excel_name="", image_name="", txt_name_list=[]):
    '''
    Output
    file_name: File's Name
    parents: [File Id]
    '''

    if image_name != "":
        image_metadata = {'name': image_name, 'parents': parents,}
        image_media = MediaFileUpload(image_name, mimetype='image/png')
        # if image_file_id := file_exist(image_name, 'image/png'):
        #     service_drive.files().update(fileId= image_file_id, body={'name': image_name}, media_body=image_media, fields='id').execute()['id']
        # else:
        image_file_id = service_drive.files().create(body=image_metadata, media_body=image_media, fields='id').execute()['id']
        image_media=None
    
    if txt_name_list != []:
        for txt_name in txt_name_list:
            text_metadata = {'name': txt_name,'parents': parents,}
            text_media = MediaFileUpload(txt_name, mimetype='text/plain')
            # if text_file_id := file_exist(txt_name, 'text/plain'):
            #     service_drive.files().update(fileId=text_file_id, body={'name': txt_name}, media_body=text_media, fields='id').execute()['id']
            # else:
            text_file_id = service_drive.files().create(body=text_metadata, media_body=text_media, fields='id').execute()['id']
            text_media=None

    if excel_name != "":
        excel_metadata = {'name': excel_name,'parents': parents}
        excel_media = MediaFileUpload(excel_name, mimetype='application/vnd.openxmlformats-officedocument.spreadsheetml.sheet')
        # if excel_file_id := file_exist(excel_name, 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet'):
        #     service_drive.files().update(fileId=excel_file_id, body={'name': excel_name}, media_body=excel_media, fields='id').execute()['id']
        # else:
        excel_file_id = service_drive.files().create(body=excel_metadata, media_body=excel_media, fields='id').execute()['id']
        excel_media=None

#get sheet list
sheet_res = service_sheet.spreadsheets().get(spreadsheetId=GOOGLE_SHEET_ID).execute()
dataset = service_sheet.spreadsheets().values().get(
        spreadsheetId= sheet_res['spreadsheetId'],
        range=sheet_res['sheets'][0]['properties']['title'],
        majorDimension= 'ROWS',
    ).execute()
google_sheet_df = pd.DataFrame(dataset['values'])
google_sheet_df = google_sheet_df.rename(columns=google_sheet_df.iloc[0]).drop(google_sheet_df.index[0])
google_sheet_df = google_sheet_df[google_sheet_df['Date'] == today_str]

def run_program(form_id, folder_input_id, folder_output_today_id, is_kimseng=False):
    df_input, excel_input_name_list = create_excel_input(form_id)
    if len(excel_input_name_list) > 1:
        #this is the duplicate file if exist
        upload_input_file(excel_input_name_list[1], [folder_output_today_id])
        os.remove(excel_input_name_list[1])
    upload_input_file(excel_input_name_list[0], [folder_input_id])
    os.remove(excel_input_name_list[0])
    
    excel_output_path, image_output_path, txt_name_list = create_all_output(df_input, is_kimseng)
    upload_output_file([folder_output_today_id], excel_name=excel_output_path, image_name=image_output_path, txt_name_list=txt_name_list)
    os.remove(excel_output_path)
    os.remove(image_output_path)
    [os.remove(txt_name) for txt_name in txt_name_list]
    return df_input

def clean_text(text):
    '''
    from https://docs.google.com/forms/d/1q9p8iXFZl-aSsxpeci4FhgWE2GIn_-xLuNI_yzhy0lY/edit?usp=drive_web to 1q9p8iXFZl-aSsxpeci4FhgWE2GIn_-xLuNI_yzhy0lY
    '''
    google_form_id = re.search('/d/(.*)/edit', text).group(1)
    # print("text: ", text)
    # print("google_form_id: ", google_form_id)
    return google_form_id

# Kimseng
ks_df_input = hyk_df_input = pd.DataFrame()
kimseng_form_id = clean_text(google_sheet_df["KimSeng"].item())
if kimseng_form_id != "None":
    ks_df_input = run_program(kimseng_form_id, input_folder_id, output_folder_today_id, is_kimseng=True)

#hyk
hyk_form_id = clean_text(google_sheet_df["HYK"].item())
if hyk_form_id != "None":
    hyk_df_input = run_program(hyk_form_id, input_folder_id, output_folder_today_id, is_kimseng=False)

if not ks_df_input.empty and not hyk_df_input.empty:
    #kshyk combined text
    kshyk_text_name_list=['KSHYK driver.txt', 'Parttimer Salary.txt']
    ks_hyk_helper_obj.output_text_kshyk(ks_df_input, hyk_df_input, kshyk_text_name_list)
    upload_output_file([output_folder_today_id], txt_name_list=kshyk_text_name_list)
    [os.remove(txt_name) for txt_name in kshyk_text_name_list]

    #calculations
    FILE_NAME = 'Kimseng Calculator.xlsx'
    OUTPUT_FILE_NAME = f'{today_str} {FILE_NAME}'

    #get from drive
    logging.info(f"Calculating cost using Kimseng Calculator...")
    file_id = service_drive.files().list(q=f"name='KimSeng Calculator.xlsx' and trashed=false and parents in '{SHARED_PARENT_FOLDER_ID}'", spaces='drive',).execute()['files'][0]['id']
    request = service_drive.files().get_media(fileId=file_id)
    try:
        file = io.BytesIO()
        downloader = MediaIoBaseDownload(file, request)
        done = False
        while done is False:
            status, done = downloader.next_chunk()
        logging.info(f'Download {int(status.progress() * 100)}.')
    except HttpError as error:
        logging(f'An error occurred: {error}')
        file = None
    
    if file != None:
        xlsx = io.BytesIO(file.getvalue())
        df_acc = pd.read_excel(xlsx, sheet_name='Sheet1')

        #start calculation
        hyk_quantities= df_acc.apply(lambda row: list(hyk_df_input['Set']).count(row['Code']) , axis=1)
        kimseng_quantity= ks_df_input['Email Address'].count()

        workbook_data_only = load_workbook(filename= FILE_NAME, data_only=False)
        ws_data = workbook_data_only.get_sheet_by_name('Sheet1') #initial data

        for index, quantity in enumerate(hyk_quantities):
            ws_data[f'B{index+2}'] = quantity

        ws_data[f'C2'] = kimseng_quantity
        workbook_data_only.save(OUTPUT_FILE_NAME)
        upload_output_file([output_folder_today_id], excel_name=OUTPUT_FILE_NAME)
        os.remove(OUTPUT_FILE_NAME)
        logging.info(f"Calculation Done!")
    else:
        logging.info(f"No KimSeng Calculator found! exiting...")
# Out:
# form['linkedSheetId'] 18vjSnU6RKt8aPPWnH5H8OYkTt7lEZY0KiEeC7a3dSA0
# df_original:               Timestamp                 Email Address  \
# 1   1/29/2023 14:20:59        rachelng0711@gmail.com
# 2   1/29/2023 14:32:51         ongruiyan00@gmail.com
# 3   1/29/2023 16:23:50            hychan03@gmail.com
# 4   1/29/2023 16:24:00         lingjazzlyn@gmail.com
# 5   1/29/2023 19:06:07          nismorris3@gmail.com
# 6   1/29/2023 19:21:50      22055135@siswa.um.edu.my
# 7   1/29/2023 19:43:55       gohnuowee1997@gmail.com
# 8   1/29/2023 19:58:57         ligee_ang@hotmail.com
# 9   1/29/2023 19:59:47         ligee_ang@hotmail.com
# 10  1/29/2023 20:01:30             yzyzlee@gmail.com
# 11  1/29/2023 20:01:37               zwgoh@yahoo.com
# 12  1/29/2023 20:04:36       gordonchong80@gmail.com
# 13  1/29/2023 20:04:46       snowmanchin03@gmail.com
# 14  1/29/2023 20:05:57     tiongchiongkian@gmail.com
# 15  1/29/2023 20:10:14  robertyongchengbin@gmail.com
# 16  1/29/2023 20:10:47       wilson.ng.miu@gmail.com
# 17  1/29/2023 20:11:53  robertyongchengbin@gmail.com
# 18  1/29/2023 20:16:21         meiqi298203@gmail.com
# 19  1/29/2023 20:16:30      xingyiiyap7716@gmail.com
# 20  1/29/2023 20:20:43     graceevaconahap@gmail.com
# 21  1/29/2023 20:37:03       ganhuixin2003@gmail.com
# 22  1/29/2023 20:41:45             jcquah2@gmail.com
# 23  1/29/2023 20:42:00      chankaiwen2003@gmail.com
# 24  1/29/2023 21:15:06         yjchan.jing@gmail.com
# 25  1/29/2023 21:30:34       zhengli010103@gmail.com
# 26  1/29/2023 21:35:01           huaenchan@gmail.com
# 27  1/29/2023 21:41:23      s2175757@siswa.um.edu.my
# 28  1/29/2023 21:45:50       lawlihdong123@gmail.com
# 29  1/29/2023 21:59:24        samson.t2000@gmail.com
# 30  1/29/2023 22:02:04             jieru03@gmail.com
# 31  1/29/2023 22:12:02          tanjiaxuen@gmail.com
# 32  1/29/2023 22:30:00             ngio_hy@yahoo.com
# 33  1/29/2023 22:41:41     thomaszhao10038@gmail.com
# 34  1/29/2023 22:45:36         laijingc386@gmail.com
# 35  1/29/2023 22:54:19          calven2232@gmail.com
# 36  1/29/2023 23:06:59           yunxinnnn@gmail.com
# 37  1/29/2023 23:11:53           tan016857@gmail.com
# 38  1/29/2023 23:30:19      chrysjerry0625@gmail.com
# 39  1/29/2023 23:30:53       vanessatingmy@gmail.com
#
#    Contact No. (For purpose of food arrival notification)  \
# 1                                          0125943465
# 2                                                  11
# 3                                          0178620215
# 4                                          0179854833
# 5                                           122779370
# 6                                          0175812616
# 7                                          0186947366
# 8                                          0182269227
# 9                                          0182269227
# 10                                         0135289858
# 11                                        01116920606
# 12                                          183723188
# 13                                         0187821066
# 14                                        60175085155
# 15                                        01110519712
# 16                                         0108292879
# 17                                        01110519712
# 18                                         0103178867
# 19                                         0104487716
# 20                                        01133775974
# 21                                        01162039373
# 22                                         1110689376
# 23                                         0143206366
# 24                                        013-3112992
# 25                                        01116011466
# 26                                         0167508667
# 27                                         0126842894
# 28                                          019861369
# 29                                         0168700282
# 30                                         0166226720
# 31                                         0108309211
# 32                                                  1
# 33                                         0183137168
# 34                                        01159937338
# 35                                         0194514475
# 36                                         0197788810
# 37                                         0177068806
# 38                                        014-9595371
# 39                                         0168919959
#
#          Name + Order No.                         KimSeng Food Pick Up Point  \
# 1       Rachel Ng Jie Yee                               KK1 - Drop Off Table
# 2                    Ory1                            KK6 - Lobby White Table
# 3                 Chan HY                               KK1 - Drop Off Table
# 4              蒸水蛋前也要加酱油的                               KK3 - Drop Off Table
# 5                   Nis 1               Dental Fac - Balai Ungku Aziz tables
# 6           WONG JING WEN                      KK7 - Seats at dewan entrance
# 7             GOH NUO WEE                             Engine Fac - BME Foyer
# 8                     bms                       Pacific Star - CAPELLA table
# 9                     bms                       Pacific Star - CAPELLA table
# 10          Lee You Zheng                  KK2 - Table in front of Mini Mart
# 11           Goh Zhen wei               Dental Fac - Balai Ungku Aziz tables
# 12          Gordon Chong                             KK6 - Lobby White Table
# 13         CHIN XUE TING                            KK8 - Dewan Seri Mutiara
# 14      TIONG CHIONG KIAN                            KK6 - Lobby White Table
# 15               Robert 1                                   KK9 - Hall Table
# 16                   Wil                   KK2 - Table in front of Mini Mart
# 17               Robert 2                                   KK9 - Hall Table
# 18             TAN MEI QI                                   KK9 - Hall Table
# 19                    YXY                            KK6 - Lobby White Table
# 20                Grace C                               KK1 - Drop Off Table
# 21            Gan Hui Xin                  KK2 - Table in front of Mini Mart
# 22         Quah Jun Chuan                           KK8 - Dewan Seri Mutiara
# 23                 Kaiwen                           KK8 - Dewan Seri Mutiara
# 24        Chan Yong Jing              Sc Fac - Study Room in DK4 (1st floor)
# 25                     Zl                           Pacific Star - ETA table
# 26                Justin                Dental Fac - Balai Ungku Aziz tables
# 27                Adeline                            KK6 - Lobby White Table
# 28   要不是因为final 要读书 我才不想来             Sc Fac - Study Room in DK4 (1st floor)
# 29             Darren Tan                  KK2 - Table in front of Mini Mart
# 30           Phang Jie Ru                            KK6 - Lobby White Table
# 31                Natasha  KK12 - Block D Benches (near Bank Islam ATM ma...
# 32                   hy1                             KK6 - Lobby White Table
# 33        Chang Zhao Xuan                            KK6 - Lobby White Table
# 34          Lai Chen Jing    KK12 - Block A Benches (near 2nd entrance gate)
# 35  CALVEN LIMMMMMMMMMMMM                            KK6 - Lobby White Table
# 36                 Megan   KK12 - Block D Benches (near Bank Islam ATM ma...
# 37                 Ze xiu                            KK6 - Lobby White Table
# 38                  Chrys  KK12 - Block D Benches (near Bank Islam ATM ma...
# 39                Vanessa                                   KK9 - Hall Table
#
#                              Menu (Maximum 3 choices)  \
# 1   荷包蛋 (Sunny Side Up), 咕噜肉 (Gu Lu Pork), 包菜 (Cab...
# 2   马铃薯炒肉 (Stir Fry Pork with Potato), Crab Nugget...
# 3   蒙古鸡 (Mongolian Chicken), 肉丸 (Meatballs), 羊角豆 (...
# 4   蒸蛋 (Steamed Egg), 蒙古鸡 (Mongolian Chicken), 日本豆...
# 5   蒙古鸡 (Mongolian Chicken), 蒸猪肉 (Steamed Pork), 羊...
# 6   蒸蛋 (Steamed Egg), 甜酸肉片 (Sweet & Sour Pork), Cr...
# 7   蒙古鸡 (Mongolian Chicken), 甜酸肉片 (Sweet & Sour Po...
# 8   甜酸肉片 (Sweet & Sour Pork), Crab Nugget, 羊角豆 (La...
# 9   甜酸肉片 (Sweet & Sour Pork), Crab Nugget, 羊角豆 (La...
# 10  荷包蛋 (Sunny Side Up), 蒙古鸡 (Mongolian Chicken), ...
# 11  蒙古鸡 (Mongolian Chicken), 肉碎豆腐 (Tofu with Mince...
# 12  咕噜肉 (Gu Lu Pork), 肉丸 (Meatballs), 羊角豆 (Ladies ...
# 13  蒸蛋 (Steamed Egg), 黑猪肉 (Black Sauce Pork), 马铃薯炒...
# 14  咕噜肉 (Gu Lu Pork), 甜酸肉片 (Sweet & Sour Pork), 咖喱...
# 15  炸鸡肉条 (Fried Chicken Strip), 甜酸肉片 (Sweet & Sour...
# 16  荷包蛋 (Sunny Side Up), 蒙古鸡 (Mongolian Chicken), ...
# 17  炸鸡肉条 (Fried Chicken Strip), 甜酸肉片 (Sweet & Sour...
# 18               黑猪肉 (Black Sauce Pork), 包菜 (Cabbage)
# 19  芙蓉蛋 (Chinese Omelet), 甜酸肉片 (Sweet & Sour Pork)...
# 20  咕噜肉 (Gu Lu Pork), 蒸猪肉 (Steamed Pork), 包菜 (Cabb...
# 21  蒙古鸡 (Mongolian Chicken), 午餐肉 (Luncheon Meat), ...
# 22  芙蓉蛋 (Chinese Omelet), 咕噜肉 (Gu Lu Pork), 咖喱菜 (C...
# 23  蒸蛋 (Steamed Egg), 蒙古鸡 (Mongolian Chicken), 日本豆...
# 24  蒸蛋 (Steamed Egg), 黑猪肉 (Black Sauce Pork), 羊角豆 ...
# 25  炸猪肉条 (Fried Pork Strip), 甜酸肉片 (Sweet & Sour Pork)
# 26  蒸蛋 (Steamed Egg), 黑猪肉 (Black Sauce Pork), 日本豆腐...
# 27  蒸蛋 (Steamed Egg), 炸猪肉条 (Fried Pork Strip), 咕噜肉...
# 28  甜酸肉片 (Sweet & Sour Pork), 肉丸 (Meatballs), 包菜 (...
# 29  芙蓉蛋 (Chinese Omelet), 炸鸡肉条 (Fried Chicken Stri...
# 30  芙蓉蛋 (Chinese Omelet), 炸鸡肉条 (Fried Chicken Stri...
# 31  芙蓉蛋 (Chinese Omelet), 咕噜肉 (Gu Lu Pork), 苦瓜 (Bi...
# 32  炸鸡肉条 (Fried Chicken Strip), 蒙古鸡 (Mongolian Chi...
# 33  蒙古鸡 (Mongolian Chicken), 日本豆腐 (Japanese Tofu),...
# 34  蒸蛋 (Steamed Egg), 咕噜肉 (Gu Lu Pork), 苦瓜 (Bitter...
# 35  芙蓉蛋 (Chinese Omelet), 肉丸 (Meatballs), 蒸猪肉 (Ste...
# 36  咕噜肉 (Gu Lu Pork), 蒸猪肉 (Steamed Pork), 羊角豆 (Lad...
# 37  蒙古鸡 (Mongolian Chicken), 咕噜肉 (Gu Lu Pork), 午餐肉...
# 38  肉碎豆腐 (Tofu with Minced Pork), Crab Nugget, 咖喱菜...
# 39  炸鸡肉条 (Fried Chicken Strip), 马铃薯炒肉 (Stir Fry Po...
#
#              Customization （Omit if not applicable)  \
# 1            **少饭 (Less Rice)**, **不要汁 (No Broth)**
# 2                                **不要汁 (No Broth)**
# 3                                **不要汁 (No Broth)**
# 4                               **加饭 (Extra Rice)**
# 5                               **加饭 (Extra Rice)**
# 6                                **少饭 (Less Rice)**
# 7   **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 8    **少饭 (Less Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 9    **少饭 (Less Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 10                       **淋咖喱汁 (Add Curry Broth)**
# 11  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 12  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 13                               **少饭 (Less Rice)**
# 14  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 15  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 16  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 17  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 18  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 19  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 20                       **淋咖喱汁 (Add Curry Broth)**
# 21  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 22  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 23  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 24                               **少饭 (Less Rice)**
# 25          **加饭 (Extra Rice)**, **不要汁 (No Broth)**
# 26  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 27   **少饭 (Less Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 28                               **少饭 (Less Rice)**
# 29
# 30   **少饭 (Less Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 31                               **少饭 (Less Rice)**
# 32                       **淋咖喱汁 (Add Curry Broth)**
# 33
# 34  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 35  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 36   **少饭 (Less Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 37   **少饭 (Less Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 38  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 39                       **淋咖喱汁 (Add Curry Broth)**
#
#                                    Receipt of Payment
# 1   https://drive.google.com/open?id=1m26JH8ItP_ua...
# 2   https://drive.google.com/open?id=1nCb1aoIRmZJh...
# 3   https://drive.google.com/open?id=1kfoq7ZIUtvRt...
# 4   https://drive.google.com/open?id=1Dm790qlWGWFI...
# 5   https://drive.google.com/open?id=11HOSB80GHT1k...
# 6   https://drive.google.com/open?id=1oiSG8ATUi517...
# 7   https://drive.google.com/open?id=1tiDR5FYpS34a...
# 8   https://drive.google.com/open?id=1bOZLAq1LY4-U...
# 9   https://drive.google.com/open?id=1miBl_s9X4LXj...
# 10  https://drive.google.com/open?id=1x6cEykFhQ5Ei...
# 11  https://drive.google.com/open?id=1jSE4jHwwAWzF...
# 12  https://drive.google.com/open?id=1ZX6PhJIzOPXk...
# 13  https://drive.google.com/open?id=1e-kUYDszdnMj...
# 14  https://drive.google.com/open?id=1yrlrN3k39zm4...
# 15  https://drive.google.com/open?id=1t2-qf84DW3me...
# 16  https://drive.google.com/open?id=1OlUFBfhWgShI...
# 17  https://drive.google.com/open?id=14RT-Jt_8yqwa...
# 18  https://drive.google.com/open?id=10H-9PnpoI9nD...
# 19  https://drive.google.com/open?id=1EkIj63dxLimv...
# 20  https://drive.google.com/open?id=1yw0EJ5sXDDFX...
# 21  https://drive.google.com/open?id=1lfIbjAd3jXlY...
# 22  https://drive.google.com/open?id=17YnD5uqorEvn...
# 23  https://drive.google.com/open?id=1v4TPbzOSWClo...
# 24  https://drive.google.com/open?id=1EC-vfMIu74Xl...
# 25  https://drive.google.com/open?id=1-RVmTsl4Ph7d...
# 26  https://drive.google.com/open?id=1c9cHdEKft19T...
# 27  https://drive.google.com/open?id=1YFfExOw_do2K...
# 28  https://drive.google.com/open?id=14oNdOrsJ3jL1...
# 29  https://drive.google.com/open?id=11B10dYf2klV1...
# 30  https://drive.google.com/open?id=1j1lxajKFD-lm...
# 31  https://drive.google.com/open?id=1Z_OeJhy4gI1I...
# 32  https://drive.google.com/open?id=12Z10BAXNbSpC...
# 33  https://drive.google.com/open?id=1U7RtPDrVo1iS...
# 34  https://drive.google.com/open?id=1GJs3qlSk-vD7...
# 35  https://drive.google.com/open?id=1q7DkY9x0Q7pB...
# 36  https://drive.google.com/open?id=1Ha6Q2ka62PRH...
# 37  https://drive.google.com/open?id=155ZhpiJPwsV0...
# 38  https://drive.google.com/open?id=1IfZi0bQatH9Q...
# 39  https://drive.google.com/open?id=1tGWwK6QPKOpV...
# df_duplicated:              Timestamp          Email Address  \
# 9  1/29/2023 19:59:47  ligee_ang@hotmail.com
#
#   Contact No. (For purpose of food arrival notification) Name + Order No.  \
# 9                                         0182269227                  bms
#
#      KimSeng Food Pick Up Point  \
# 9  Pacific Star - CAPELLA table
#
#                             Menu (Maximum 3 choices)  \
# 9  甜酸肉片 (Sweet & Sour Pork), Crab Nugget, 羊角豆 (La...
#
#            Customization （Omit if not applicable)  \
# 9  **少饭 (Less Rice)**, **淋咖喱汁 (Add Curry Broth)**
#
#                                   Receipt of Payment
# 9  https://drive.google.com/open?id=1miBl_s9X4LXj...
# df after drop inplace:               Timestamp                 Email Address  \
# 1   1/29/2023 14:20:59        rachelng0711@gmail.com
# 2   1/29/2023 14:32:51         ongruiyan00@gmail.com
# 3   1/29/2023 16:23:50            hychan03@gmail.com
# 4   1/29/2023 16:24:00         lingjazzlyn@gmail.com
# 5   1/29/2023 19:06:07          nismorris3@gmail.com
# 6   1/29/2023 19:21:50      22055135@siswa.um.edu.my
# 7   1/29/2023 19:43:55       gohnuowee1997@gmail.com
# 8   1/29/2023 19:58:57         ligee_ang@hotmail.com
# 10  1/29/2023 20:01:30             yzyzlee@gmail.com
# 11  1/29/2023 20:01:37               zwgoh@yahoo.com
# 12  1/29/2023 20:04:36       gordonchong80@gmail.com
# 13  1/29/2023 20:04:46       snowmanchin03@gmail.com
# 14  1/29/2023 20:05:57     tiongchiongkian@gmail.com
# 15  1/29/2023 20:10:14  robertyongchengbin@gmail.com
# 16  1/29/2023 20:10:47       wilson.ng.miu@gmail.com
# 17  1/29/2023 20:11:53  robertyongchengbin@gmail.com
# 18  1/29/2023 20:16:21         meiqi298203@gmail.com
# 19  1/29/2023 20:16:30      xingyiiyap7716@gmail.com
# 20  1/29/2023 20:20:43     graceevaconahap@gmail.com
# 21  1/29/2023 20:37:03       ganhuixin2003@gmail.com
# 22  1/29/2023 20:41:45             jcquah2@gmail.com
# 23  1/29/2023 20:42:00      chankaiwen2003@gmail.com
# 24  1/29/2023 21:15:06         yjchan.jing@gmail.com
# 25  1/29/2023 21:30:34       zhengli010103@gmail.com
# 26  1/29/2023 21:35:01           huaenchan@gmail.com
# 27  1/29/2023 21:41:23      s2175757@siswa.um.edu.my
# 28  1/29/2023 21:45:50       lawlihdong123@gmail.com
# 29  1/29/2023 21:59:24        samson.t2000@gmail.com
# 30  1/29/2023 22:02:04             jieru03@gmail.com
# 31  1/29/2023 22:12:02          tanjiaxuen@gmail.com
# 32  1/29/2023 22:30:00             ngio_hy@yahoo.com
# 33  1/29/2023 22:41:41     thomaszhao10038@gmail.com
# 34  1/29/2023 22:45:36         laijingc386@gmail.com
# 35  1/29/2023 22:54:19          calven2232@gmail.com
# 36  1/29/2023 23:06:59           yunxinnnn@gmail.com
# 37  1/29/2023 23:11:53           tan016857@gmail.com
# 38  1/29/2023 23:30:19      chrysjerry0625@gmail.com
# 39  1/29/2023 23:30:53       vanessatingmy@gmail.com
#
#    Contact No. (For purpose of food arrival notification)  \
# 1                                          0125943465
# 2                                                  11
# 3                                          0178620215
# 4                                          0179854833
# 5                                           122779370
# 6                                          0175812616
# 7                                          0186947366
# 8                                          0182269227
# 10                                         0135289858
# 11                                        01116920606
# 12                                          183723188
# 13                                         0187821066
# 14                                        60175085155
# 15                                        01110519712
# 16                                         0108292879
# 17                                        01110519712
# 18                                         0103178867
# 19                                         0104487716
# 20                                        01133775974
# 21                                        01162039373
# 22                                         1110689376
# 23                                         0143206366
# 24                                        013-3112992
# 25                                        01116011466
# 26                                         0167508667
# 27                                         0126842894
# 28                                          019861369
# 29                                         0168700282
# 30                                         0166226720
# 31                                         0108309211
# 32                                                  1
# 33                                         0183137168
# 34                                        01159937338
# 35                                         0194514475
# 36                                         0197788810
# 37                                         0177068806
# 38                                        014-9595371
# 39                                         0168919959
#
#          Name + Order No.                         KimSeng Food Pick Up Point  \
# 1       Rachel Ng Jie Yee                               KK1 - Drop Off Table
# 2                    Ory1                            KK6 - Lobby White Table
# 3                 Chan HY                               KK1 - Drop Off Table
# 4              蒸水蛋前也要加酱油的                               KK3 - Drop Off Table
# 5                   Nis 1               Dental Fac - Balai Ungku Aziz tables
# 6           WONG JING WEN                      KK7 - Seats at dewan entrance
# 7             GOH NUO WEE                             Engine Fac - BME Foyer
# 8                     bms                       Pacific Star - CAPELLA table
# 10          Lee You Zheng                  KK2 - Table in front of Mini Mart
# 11           Goh Zhen wei               Dental Fac - Balai Ungku Aziz tables
# 12          Gordon Chong                             KK6 - Lobby White Table
# 13         CHIN XUE TING                            KK8 - Dewan Seri Mutiara
# 14      TIONG CHIONG KIAN                            KK6 - Lobby White Table
# 15               Robert 1                                   KK9 - Hall Table
# 16                   Wil                   KK2 - Table in front of Mini Mart
# 17               Robert 2                                   KK9 - Hall Table
# 18             TAN MEI QI                                   KK9 - Hall Table
# 19                    YXY                            KK6 - Lobby White Table
# 20                Grace C                               KK1 - Drop Off Table
# 21            Gan Hui Xin                  KK2 - Table in front of Mini Mart
# 22         Quah Jun Chuan                           KK8 - Dewan Seri Mutiara
# 23                 Kaiwen                           KK8 - Dewan Seri Mutiara
# 24        Chan Yong Jing              Sc Fac - Study Room in DK4 (1st floor)
# 25                     Zl                           Pacific Star - ETA table
# 26                Justin                Dental Fac - Balai Ungku Aziz tables
# 27                Adeline                            KK6 - Lobby White Table
# 28   要不是因为final 要读书 我才不想来             Sc Fac - Study Room in DK4 (1st floor)
# 29             Darren Tan                  KK2 - Table in front of Mini Mart
# 30           Phang Jie Ru                            KK6 - Lobby White Table
# 31                Natasha  KK12 - Block D Benches (near Bank Islam ATM ma...
# 32                   hy1                             KK6 - Lobby White Table
# 33        Chang Zhao Xuan                            KK6 - Lobby White Table
# 34          Lai Chen Jing    KK12 - Block A Benches (near 2nd entrance gate)
# 35  CALVEN LIMMMMMMMMMMMM                            KK6 - Lobby White Table
# 36                 Megan   KK12 - Block D Benches (near Bank Islam ATM ma...
# 37                 Ze xiu                            KK6 - Lobby White Table
# 38                  Chrys  KK12 - Block D Benches (near Bank Islam ATM ma...
# 39                Vanessa                                   KK9 - Hall Table
#
#                              Menu (Maximum 3 choices)  \
# 1   荷包蛋 (Sunny Side Up), 咕噜肉 (Gu Lu Pork), 包菜 (Cab...
# 2   马铃薯炒肉 (Stir Fry Pork with Potato), Crab Nugget...
# 3   蒙古鸡 (Mongolian Chicken), 肉丸 (Meatballs), 羊角豆 (...
# 4   蒸蛋 (Steamed Egg), 蒙古鸡 (Mongolian Chicken), 日本豆...
# 5   蒙古鸡 (Mongolian Chicken), 蒸猪肉 (Steamed Pork), 羊...
# 6   蒸蛋 (Steamed Egg), 甜酸肉片 (Sweet & Sour Pork), Cr...
# 7   蒙古鸡 (Mongolian Chicken), 甜酸肉片 (Sweet & Sour Po...
# 8   甜酸肉片 (Sweet & Sour Pork), Crab Nugget, 羊角豆 (La...
# 10  荷包蛋 (Sunny Side Up), 蒙古鸡 (Mongolian Chicken), ...
# 11  蒙古鸡 (Mongolian Chicken), 肉碎豆腐 (Tofu with Mince...
# 12  咕噜肉 (Gu Lu Pork), 肉丸 (Meatballs), 羊角豆 (Ladies ...
# 13  蒸蛋 (Steamed Egg), 黑猪肉 (Black Sauce Pork), 马铃薯炒...
# 14  咕噜肉 (Gu Lu Pork), 甜酸肉片 (Sweet & Sour Pork), 咖喱...
# 15  炸鸡肉条 (Fried Chicken Strip), 甜酸肉片 (Sweet & Sour...
# 16  荷包蛋 (Sunny Side Up), 蒙古鸡 (Mongolian Chicken), ...
# 17  炸鸡肉条 (Fried Chicken Strip), 甜酸肉片 (Sweet & Sour...
# 18               黑猪肉 (Black Sauce Pork), 包菜 (Cabbage)
# 19  芙蓉蛋 (Chinese Omelet), 甜酸肉片 (Sweet & Sour Pork)...
# 20  咕噜肉 (Gu Lu Pork), 蒸猪肉 (Steamed Pork), 包菜 (Cabb...
# 21  蒙古鸡 (Mongolian Chicken), 午餐肉 (Luncheon Meat), ...
# 22  芙蓉蛋 (Chinese Omelet), 咕噜肉 (Gu Lu Pork), 咖喱菜 (C...
# 23  蒸蛋 (Steamed Egg), 蒙古鸡 (Mongolian Chicken), 日本豆...
# 24  蒸蛋 (Steamed Egg), 黑猪肉 (Black Sauce Pork), 羊角豆 ...
# 25  炸猪肉条 (Fried Pork Strip), 甜酸肉片 (Sweet & Sour Pork)
# 26  蒸蛋 (Steamed Egg), 黑猪肉 (Black Sauce Pork), 日本豆腐...
# 27  蒸蛋 (Steamed Egg), 炸猪肉条 (Fried Pork Strip), 咕噜肉...
# 28  甜酸肉片 (Sweet & Sour Pork), 肉丸 (Meatballs), 包菜 (...
# 29  芙蓉蛋 (Chinese Omelet), 炸鸡肉条 (Fried Chicken Stri...
# 30  芙蓉蛋 (Chinese Omelet), 炸鸡肉条 (Fried Chicken Stri...
# 31  芙蓉蛋 (Chinese Omelet), 咕噜肉 (Gu Lu Pork), 苦瓜 (Bi...
# 32  炸鸡肉条 (Fried Chicken Strip), 蒙古鸡 (Mongolian Chi...
# 33  蒙古鸡 (Mongolian Chicken), 日本豆腐 (Japanese Tofu),...
# 34  蒸蛋 (Steamed Egg), 咕噜肉 (Gu Lu Pork), 苦瓜 (Bitter...
# 35  芙蓉蛋 (Chinese Omelet), 肉丸 (Meatballs), 蒸猪肉 (Ste...
# 36  咕噜肉 (Gu Lu Pork), 蒸猪肉 (Steamed Pork), 羊角豆 (Lad...
# 37  蒙古鸡 (Mongolian Chicken), 咕噜肉 (Gu Lu Pork), 午餐肉...
# 38  肉碎豆腐 (Tofu with Minced Pork), Crab Nugget, 咖喱菜...
# 39  炸鸡肉条 (Fried Chicken Strip), 马铃薯炒肉 (Stir Fry Po...
#
#              Customization （Omit if not applicable)  \
# 1            **少饭 (Less Rice)**, **不要汁 (No Broth)**
# 2                                **不要汁 (No Broth)**
# 3                                **不要汁 (No Broth)**
# 4                               **加饭 (Extra Rice)**
# 5                               **加饭 (Extra Rice)**
# 6                                **少饭 (Less Rice)**
# 7   **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 8    **少饭 (Less Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 10                       **淋咖喱汁 (Add Curry Broth)**
# 11  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 12  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 13                               **少饭 (Less Rice)**
# 14  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 15  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 16  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 17  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 18  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 19  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 20                       **淋咖喱汁 (Add Curry Broth)**
# 21  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 22  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 23  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 24                               **少饭 (Less Rice)**
# 25          **加饭 (Extra Rice)**, **不要汁 (No Broth)**
# 26  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 27   **少饭 (Less Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 28                               **少饭 (Less Rice)**
# 29
# 30   **少饭 (Less Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 31                               **少饭 (Less Rice)**
# 32                       **淋咖喱汁 (Add Curry Broth)**
# 33
# 34  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 35  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 36   **少饭 (Less Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 37   **少饭 (Less Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 38  **加饭 (Extra Rice)**, **淋咖喱汁 (Add Curry Broth)**
# 39                       **淋咖喱汁 (Add Curry Broth)**
#
#                                    Receipt of Payment
# 1   https://drive.google.com/open?id=1m26JH8ItP_ua...
# 2   https://drive.google.com/open?id=1nCb1aoIRmZJh...
# 3   https://drive.google.com/open?id=1kfoq7ZIUtvRt...
# 4   https://drive.google.com/open?id=1Dm790qlWGWFI...
# 5   https://drive.google.com/open?id=11HOSB80GHT1k...
# 6   https://drive.google.com/open?id=1oiSG8ATUi517...
# 7   https://drive.google.com/open?id=1tiDR5FYpS34a...
# 8   https://drive.google.com/open?id=1bOZLAq1LY4-U...
# 10  https://drive.google.com/open?id=1x6cEykFhQ5Ei...
# 11  https://drive.google.com/open?id=1jSE4jHwwAWzF...
# 12  https://drive.google.com/open?id=1ZX6PhJIzOPXk...
# 13  https://drive.google.com/open?id=1e-kUYDszdnMj...
# 14  https://drive.google.com/open?id=1yrlrN3k39zm4...
# 15  https://drive.google.com/open?id=1t2-qf84DW3me...
# 16  https://drive.google.com/open?id=1OlUFBfhWgShI...
# 17  https://drive.google.com/open?id=14RT-Jt_8yqwa...
# 18  https://drive.google.com/open?id=10H-9PnpoI9nD...
# 19  https://drive.google.com/open?id=1EkIj63dxLimv...
# 20  https://drive.google.com/open?id=1yw0EJ5sXDDFX...
# 21  https://drive.google.com/open?id=1lfIbjAd3jXlY...
# 22  https://drive.google.com/open?id=17YnD5uqorEvn...
# 23  https://drive.google.com/open?id=1v4TPbzOSWClo...
# 24  https://drive.google.com/open?id=1EC-vfMIu74Xl...
# 25  https://drive.google.com/open?id=1-RVmTsl4Ph7d...
# 26  https://drive.google.com/open?id=1c9cHdEKft19T...
# 27  https://drive.google.com/open?id=1YFfExOw_do2K...
# 28  https://drive.google.com/open?id=14oNdOrsJ3jL1...
# 29  https://drive.google.com/open?id=11B10dYf2klV1...
# 30  https://drive.google.com/open?id=1j1lxajKFD-lm...
# 31  https://drive.google.com/open?id=1Z_OeJhy4gI1I...
# 32  https://drive.google.com/open?id=12Z10BAXNbSpC...
# 33  https://drive.google.com/open?id=1U7RtPDrVo1iS...
# 34  https://drive.google.com/open?id=1GJs3qlSk-vD7...
# 35  https://drive.google.com/open?id=1q7DkY9x0Q7pB...
# 36  https://drive.google.com/open?id=1Ha6Q2ka62PRH...
# 37  https://drive.google.com/open?id=155ZhpiJPwsV0...
# 38  https://drive.google.com/open?id=1IfZi0bQatH9Q...
# 39  https://drive.google.com/open?id=1tGWwK6QPKOpV...
# d:\Business Stuff\Hua yi Business\Food Delivery\mypackage\helpers.py:191: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop('Point_Rank', 1, inplace = True)
# INFO:root:Generating pickup image...
# INFO:root:Image generated in KimSeng 30-01-2023 image.jpg!
# form['linkedSheetId'] 17ze3_gf5KjRn2uyLucg7ga32OX2_f-WIytgY3XHoLLM
# df_original:               Timestamp              Email Address  \
# 1   1/29/2023 14:23:44    taneunice2003@gmail.com
# 2   1/29/2023 14:29:38      jiakaitan79@gmail.com
# 3   1/29/2023 15:15:00     elwenyip0918@gmail.com
# 4   1/29/2023 16:21:27          wattrid@gmail.com
# 5   1/29/2023 16:58:38      ooiamiko713@gmail.com
# 6   1/29/2023 18:04:14     leederkchuan@gmail.com
# 7   1/29/2023 18:44:18      lingjazzlyn@gmail.com
# 8   1/29/2023 19:33:01  kone01127740163@gmail.com
# 9   1/29/2023 20:01:15    michellehu264@gmail.com
# 10  1/29/2023 20:03:32     calvinjmy993@gmail.com
# 11  1/29/2023 20:06:25       havinash14@gmail.com
# 12  1/29/2023 20:10:16        kalokyeep@gmail.com
# 13  1/29/2023 20:16:25       lingpeixin@gmail.com
# 14  1/29/2023 20:26:51      gdtan021115@gmail.com
# 15  1/29/2023 20:38:34          swchia2@gmail.com
# 16  1/29/2023 20:41:36     leowkhaivern@gmail.com
# 17  1/29/2023 21:02:42     wongemilie@hotmail.com
# 18  1/29/2023 21:02:43      kenlieng123@gmail.com
# 19  1/29/2023 21:25:47         ctlx1216@gmail.com
# 20  1/29/2023 21:27:44    yingyingsim00@gmail.com
# 21  1/29/2023 21:35:19       zuying1204@gmail.com
# 22  1/29/2023 21:36:00       zuying1204@gmail.com
# 23  1/29/2023 21:36:36       zuying1204@gmail.com
# 24  1/29/2023 21:40:24       xinyingsoo@gmail.com
# 25  1/29/2023 21:57:11   tankuanliang03@gmail.com
# 26  1/29/2023 22:27:38        xinning35@gmail.com
# 27  1/29/2023 22:30:01    minhuilee0520@gmail.com
# 28  1/29/2023 23:04:53      weitian0216@gmail.com
# 29  1/29/2023 23:05:45  yinghuing031003@gmail.com
# 30  1/29/2023 23:26:24       tanjiaxuen@gmail.com
#
#    Contact No. (For purpose of food arrival notification)  \
# 1                                         01128277551
# 2                                         019-6676883
# 3                                         01115530638
# 4                                    +60 11-2584 2037
# 5                                          0192370389
# 6                                          0162271831
# 7                                          0179854833
# 8                                         01127740163
# 9                                          0198050437
# 10                                          123357596
# 11                                       011-11188106
# 12                                        01131389048
# 13                                         0125502882
# 14                                         0164730635
# 15                                         0182903248
# 16                                         0174817812
# 17                                         0182191696
# 18                                         0125356862
# 19                                         0177456989
# 20                                          174289275
# 21                                        01110870213
# 22                                        01110870213
# 23                                        01110870213
# 24                                        012-6388450
# 25                                        01110745285
# 26                                         0127606318
# 27                                        016 3320342
# 28                                         0177277959
# 29                                        01110835530
# 30                                         0108309211
#
#                     Name                             HYK Food Pick Up Point  \
# 1             Tan Eunice                                   KK9 - Hall Table
# 2                Jia Kai                            KK6 - Lobby White Table
# 3   ELWEN YIP CHUN YEEN                                KK3 - Drop Off Table
# 4                    Foo                       Pacific Star - CAPELLA table
# 5       Amiko Ooi Shunze  KK12 - Block D Benches (near Bank Islam ATM ma...
# 6         Lee Derk Chuan               Dental Fac - Balai Ungku Aziz tables
# 7              Ling Xin                                KK3 - Drop Off Table
# 8      Chai Ching Sheng     KK12 - Block A Benches (near 2nd entrance gate)
# 9    MICHELLE HU YNH TIN                           KK8 - Dewan Seri Mutiara
# 10               Calvin                       KK10 - Chairs at the entrance
# 11              Havinash               Dental Fac - Balai Ungku Aziz tables
# 12                Kalokk                           KK8 - Dewan Seri Mutiara
# 13                  Ling                  KK2 - Table in front of Mini Mart
# 14          Tan Guo Dong                   Ryan&Miho - MIHO drop off chairs
# 15         CHIA SIAO WEI                               KK1 - Drop Off Table
# 16        Leow Khai Vern                           KK8 - Dewan Seri Mutiara
# 17                  Wong                            KK6 - Lobby White Table
# 18            Eng Ken Li               Dental Fac - Balai Ungku Aziz tables
# 19                foodie                      KK7 - Seats at dewan entrance
# 20        Sim Ying Ying                            KK8 - Dewan Seri Mutiara
# 21                   Lim                   Ryan&Miho - RYAN drop off chairs
# 22                   Lim                   Ryan&Miho - RYAN drop off chairs
# 23                   Lim                   Ryan&Miho - RYAN drop off chairs
# 24             Xin Ying                             KK6 - Lobby White Table
# 25        TAN KUAN LIANG                  KK2 - Table in front of Mini Mart
# 26        Wong Xin Ning                Dental Fac - Balai Ungku Aziz tables
# 27           Lee Min Hui               Dental Fac - Balai Ungku Aziz tables
# 28          Tan Wei Tian               Dental Fac - Balai Ungku Aziz tables
# 29               yinghui                            KK6 - Lobby White Table
# 30                 Elena  KK12 - Block D Benches (near Bank Islam ATM ma...
#
#                                     Menu (Select One)  \
# 1   RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 2   RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 3                                RM5.5 (B-BB) Big Bao
# 4   RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 5   RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 6   RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 7                                RM5.5 (B-BB) Big Bao
# 8              RM9 (C-RPCR) Roasted Pork Chicken Rice
# 9   RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 10  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 11  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 12  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 13  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 14                            RM8 (C-CR) Chicken Rice
# 15  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 16                   RM10 (P-PCPM) Dry Chilli pan mee
# 17  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 18  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 19  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 20  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 21  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 22  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 23  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 24  RM6.3  Vegetarian Set V (Dark soy egg + bake b...
# 25  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 26  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 27  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 28  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 29  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 30  RM6.3  Spicy Set S (Dry curry pork + bake bean...
#
#                                    Receipt of Payment
# 1   https://drive.google.com/open?id=1vifUcwuKZXS8...
# 2   https://drive.google.com/open?id=13_CGHajD47ud...
# 3   https://drive.google.com/open?id=1VFkEphpEMWDg...
# 4   https://drive.google.com/open?id=1_ekujw6_wVTU...
# 5   https://drive.google.com/open?id=1tRxsBMo_mgVI...
# 6   https://drive.google.com/open?id=1CC41C29zhutu...
# 7   https://drive.google.com/open?id=1fjkXhJqfBenE...
# 8   https://drive.google.com/open?id=1l6gK_4dcW5dC...
# 9   https://drive.google.com/open?id=1XBtM1FMoDSxz...
# 10  https://drive.google.com/open?id=1PvLc6UA-3wgm...
# 11  https://drive.google.com/open?id=1f0Y7mVzZZ8K5...
# 12  https://drive.google.com/open?id=1N8tsMRZ4VRGi...
# 13  https://drive.google.com/open?id=19NV5aTBYV8WJ...
# 14  https://drive.google.com/open?id=1FDvt_gcuN5av...
# 15  https://drive.google.com/open?id=19FtpEe2GPzEj...
# 16  https://drive.google.com/open?id=1KaV2rb_tgEFG...
# 17  https://drive.google.com/open?id=1jmreW1x2KeEW...
# 18  https://drive.google.com/open?id=1G0MfRxIfuvJ0...
# 19  https://drive.google.com/open?id=1oniPpzfxn-hE...
# 20  https://drive.google.com/open?id=1hjLAclEXq1h-...
# 21  https://drive.google.com/open?id=1N-hY6UHptawa...
# 22  https://drive.google.com/open?id=1oL-8BuW8hu3F...
# 23  https://drive.google.com/open?id=1T4OlEwm8L4by...
# 24  https://drive.google.com/open?id=1yBLuwDEbA1C0...
# 25  https://drive.google.com/open?id=1szVRw3YvIHdR...
# 26  https://drive.google.com/open?id=1x6c18eLOLXgU...
# 27  https://drive.google.com/open?id=1feaw08XdmWKi...
# 28  https://drive.google.com/open?id=15o0T277baJSj...
# 29  https://drive.google.com/open?id=17N3-cvlfPSMF...
# 30  https://drive.google.com/open?id=11yhJqwfqgPiy...
# df_duplicated:               Timestamp         Email Address  \
# 22  1/29/2023 21:36:00  zuying1204@gmail.com
# 23  1/29/2023 21:36:36  zuying1204@gmail.com
#
#    Contact No. (For purpose of food arrival notification) Name  \
# 22                                        01110870213      Lim
# 23                                        01110870213      Lim
#
#               HYK Food Pick Up Point  \
# 22  Ryan&Miho - RYAN drop off chairs
# 23  Ryan&Miho - RYAN drop off chairs
#
#                                     Menu (Select One)  \
# 22  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 23  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
#
#                                    Receipt of Payment
# 22  https://drive.google.com/open?id=1oL-8BuW8hu3F...
# 23  https://drive.google.com/open?id=1T4OlEwm8L4by...
# df after drop inplace:               Timestamp              Email Address  \
# 1   1/29/2023 14:23:44    taneunice2003@gmail.com
# 2   1/29/2023 14:29:38      jiakaitan79@gmail.com
# 3   1/29/2023 15:15:00     elwenyip0918@gmail.com
# 4   1/29/2023 16:21:27          wattrid@gmail.com
# 5   1/29/2023 16:58:38      ooiamiko713@gmail.com
# 6   1/29/2023 18:04:14     leederkchuan@gmail.com
# 7   1/29/2023 18:44:18      lingjazzlyn@gmail.com
# 8   1/29/2023 19:33:01  kone01127740163@gmail.com
# 9   1/29/2023 20:01:15    michellehu264@gmail.com
# 10  1/29/2023 20:03:32     calvinjmy993@gmail.com
# 11  1/29/2023 20:06:25       havinash14@gmail.com
# 12  1/29/2023 20:10:16        kalokyeep@gmail.com
# 13  1/29/2023 20:16:25       lingpeixin@gmail.com
# 14  1/29/2023 20:26:51      gdtan021115@gmail.com
# 15  1/29/2023 20:38:34          swchia2@gmail.com
# 16  1/29/2023 20:41:36     leowkhaivern@gmail.com
# 17  1/29/2023 21:02:42     wongemilie@hotmail.com
# 18  1/29/2023 21:02:43      kenlieng123@gmail.com
# 19  1/29/2023 21:25:47         ctlx1216@gmail.com
# 20  1/29/2023 21:27:44    yingyingsim00@gmail.com
# 21  1/29/2023 21:35:19       zuying1204@gmail.com
# 24  1/29/2023 21:40:24       xinyingsoo@gmail.com
# 25  1/29/2023 21:57:11   tankuanliang03@gmail.com
# 26  1/29/2023 22:27:38        xinning35@gmail.com
# 27  1/29/2023 22:30:01    minhuilee0520@gmail.com
# 28  1/29/2023 23:04:53      weitian0216@gmail.com
# 29  1/29/2023 23:05:45  yinghuing031003@gmail.com
# 30  1/29/2023 23:26:24       tanjiaxuen@gmail.com
#
#    Contact No. (For purpose of food arrival notification)  \
# 1                                         01128277551
# 2                                         019-6676883
# 3                                         01115530638
# 4                                    +60 11-2584 2037
# 5                                          0192370389
# 6                                          0162271831
# 7                                          0179854833
# 8                                         01127740163
# 9                                          0198050437
# 10                                          123357596
# 11                                       011-11188106
# 12                                        01131389048
# 13                                         0125502882
# 14                                         0164730635
# 15                                         0182903248
# 16                                         0174817812
# 17                                         0182191696
# 18                                         0125356862
# 19                                         0177456989
# 20                                          174289275
# 21                                        01110870213
# 24                                        012-6388450
# 25                                        01110745285
# 26                                         0127606318
# 27                                        016 3320342
# 28                                         0177277959
# 29                                        01110835530
# 30                                         0108309211
#
#                     Name                             HYK Food Pick Up Point  \
# 1             Tan Eunice                                   KK9 - Hall Table
# 2                Jia Kai                            KK6 - Lobby White Table
# 3   ELWEN YIP CHUN YEEN                                KK3 - Drop Off Table
# 4                    Foo                       Pacific Star - CAPELLA table
# 5       Amiko Ooi Shunze  KK12 - Block D Benches (near Bank Islam ATM ma...
# 6         Lee Derk Chuan               Dental Fac - Balai Ungku Aziz tables
# 7              Ling Xin                                KK3 - Drop Off Table
# 8      Chai Ching Sheng     KK12 - Block A Benches (near 2nd entrance gate)
# 9    MICHELLE HU YNH TIN                           KK8 - Dewan Seri Mutiara
# 10               Calvin                       KK10 - Chairs at the entrance
# 11              Havinash               Dental Fac - Balai Ungku Aziz tables
# 12                Kalokk                           KK8 - Dewan Seri Mutiara
# 13                  Ling                  KK2 - Table in front of Mini Mart
# 14          Tan Guo Dong                   Ryan&Miho - MIHO drop off chairs
# 15         CHIA SIAO WEI                               KK1 - Drop Off Table
# 16        Leow Khai Vern                           KK8 - Dewan Seri Mutiara
# 17                  Wong                            KK6 - Lobby White Table
# 18            Eng Ken Li               Dental Fac - Balai Ungku Aziz tables
# 19                foodie                      KK7 - Seats at dewan entrance
# 20        Sim Ying Ying                            KK8 - Dewan Seri Mutiara
# 21                   Lim                   Ryan&Miho - RYAN drop off chairs
# 24             Xin Ying                             KK6 - Lobby White Table
# 25        TAN KUAN LIANG                  KK2 - Table in front of Mini Mart
# 26        Wong Xin Ning                Dental Fac - Balai Ungku Aziz tables
# 27           Lee Min Hui               Dental Fac - Balai Ungku Aziz tables
# 28          Tan Wei Tian               Dental Fac - Balai Ungku Aziz tables
# 29               yinghui                            KK6 - Lobby White Table
# 30                 Elena  KK12 - Block D Benches (near Bank Islam ATM ma...
#
#                                     Menu (Select One)  \
# 1   RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 2   RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 3                                RM5.5 (B-BB) Big Bao
# 4   RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 5   RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 6   RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 7                                RM5.5 (B-BB) Big Bao
# 8              RM9 (C-RPCR) Roasted Pork Chicken Rice
# 9   RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 10  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 11  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 12  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 13  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 14                            RM8 (C-CR) Chicken Rice
# 15  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 16                   RM10 (P-PCPM) Dry Chilli pan mee
# 17  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 18  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 19  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 20  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 21  RM6.3  Not Spicy Set N (Dark soy pork + bake b...
# 24  RM6.3  Vegetarian Set V (Dark soy egg + bake b...
# 25  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 26  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 27  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 28  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 29  RM6.3  Spicy Set S (Dry curry pork + bake bean...
# 30  RM6.3  Spicy Set S (Dry curry pork + bake bean...
#
#                                    Receipt of Payment
# 1   https://drive.google.com/open?id=1vifUcwuKZXS8...
# 2   https://drive.google.com/open?id=13_CGHajD47ud...
# 3   https://drive.google.com/open?id=1VFkEphpEMWDg...
# 4   https://drive.google.com/open?id=1_ekujw6_wVTU...
# 5   https://drive.google.com/open?id=1tRxsBMo_mgVI...
# 6   https://drive.google.com/open?id=1CC41C29zhutu...
# 7   https://drive.google.com/open?id=1fjkXhJqfBenE...
# 8   https://drive.google.com/open?id=1l6gK_4dcW5dC...
# 9   https://drive.google.com/open?id=1XBtM1FMoDSxz...
# 10  https://drive.google.com/open?id=1PvLc6UA-3wgm...
# 11  https://drive.google.com/open?id=1f0Y7mVzZZ8K5...
# 12  https://drive.google.com/open?id=1N8tsMRZ4VRGi...
# 13  https://drive.google.com/open?id=19NV5aTBYV8WJ...
# 14  https://drive.google.com/open?id=1FDvt_gcuN5av...
# 15  https://drive.google.com/open?id=19FtpEe2GPzEj...
# 16  https://drive.google.com/open?id=1KaV2rb_tgEFG...
# 17  https://drive.google.com/open?id=1jmreW1x2KeEW...
# 18  https://drive.google.com/open?id=1G0MfRxIfuvJ0...
# 19  https://drive.google.com/open?id=1oniPpzfxn-hE...
# 20  https://drive.google.com/open?id=1hjLAclEXq1h-...
# 21  https://drive.google.com/open?id=1N-hY6UHptawa...
# 24  https://drive.google.com/open?id=1yBLuwDEbA1C0...
# 25  https://drive.google.com/open?id=1szVRw3YvIHdR...
# 26  https://drive.google.com/open?id=1x6c18eLOLXgU...
# 27  https://drive.google.com/open?id=1feaw08XdmWKi...
# 28  https://drive.google.com/open?id=15o0T277baJSj...
# 29  https://drive.google.com/open?id=17N3-cvlfPSMF...
# 30  https://drive.google.com/open?id=11yhJqwfqgPiy...
# d:\Business Stuff\Hua yi Business\Food Delivery\mypackage\helpers.py:394: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop('Point_Rank', 1, inplace = True)
# INFO:root:Generating pickup image...
# INFO:root:Image generated in HYK 30-01-2023 image.jpg!
# INFO:root:Calculating cost using Kimseng Calculator...
# INFO:root:Download 100.
# C:\Users\USER\AppData\Local\Temp\ipykernel_23312\433062415.py:141: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   ws_data = workbook_data_only.get_sheet_by_name('Sheet1') #initial data
# INFO:root:Calculation Done!

# %%
# service_drive.files().get(fileId="1wqGRN9e-iMY3okNl0KUEnT7gwqjqtiv9WGIvo18fvKc?").execute()
# file_id = service_drive.files().list(q=f"name='KimSeng Calculator.xlsx' and trashed=false and parents in '{SHARED_PARENT_FOLDER_ID}'", spaces='drive',).execute()['files'][0]['id']
# file_id = service_drive.files().list(q=f"name='KimSeng Calculator.xlsx' and trashed=false and parents in '{SHARED_PARENT_FOLDER_ID}'", spaces='drive',).execute()['files'][0]['id']
# request = service_drive.files().get_media(fileId=file_id)
# file = io.BytesIO()
# downloader = MediaIoBaseDownload(file, request)
# done = False
# while done is False:
#     status, done = downloader.next_chunk()
#     print(F'Download {int(status.progress() * 100)}.')

# %%
# # Request body for creating a form
# NEW_FORM = {
#     "info": {
#         "title": "Quickstart form",
#     }
# }

# # Request body to add a multiple-choice question
# NEW_QUESTION = {
#     "requests": [{
#         "createItem": {
#             "item": {
#                 "title": "In what year did the United States land a mission on the moon?",
#                 "questionItem": {
#                     "question": {
#                         "required": True,
#                         "choiceQuestion": {
#                             "type": "RADIO",
#                             "options": [
#                                 {"value": "1965"},
#                                 {"value": "1967"},
#                                 {"value": "1969"},
#                                 {"value": "1971"}
#                             ],
#                             "shuffle": True
#                         }
#                     }
#                 },
#             },
#             "location": {
#                 "index": 0
#             }
#         }
#     }]
# }

# # Creates the initial form
# # result = form_service.forms().create(body=NEW_FORM).execute()

# # Adds the question to the form
# # question_setting = form_service.forms().batchUpdate(formId=result["formId"], body=NEW_QUESTION).execute()

# # Prints the result to show the question has been added
# get_result = form_service.forms().get(formId="1q9p8iXFZl-aSsxpeci4FhgWE2GIn_-xLuNI_yzhy0lY").execute()
# print(get_result)
